# %%
import pandas as pd
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
houses = pd.read_excel('Real estate valuation data set.xlsx')

# %%
houses.head(10)
# Out:
#    house_age  MRTS_distance  CS_nos  Price_house
# 0       32.0       84.87882      10         37.9
# 1       19.5      306.59470       9         42.2
# 2       13.3      561.98450       5         47.3
# 3       13.3      561.98450       5         54.8
# 4        5.0      390.56840       5         43.1
# 5        7.1     2175.03000       3         32.1
# 6       34.5      623.47310       7         40.3
# 7       20.3      287.60250       6         46.7
# 8       31.7     5512.03800       1         18.8
# 9       17.9     1783.18000       3         22.1

# %%
houses.sample(3)
# Out:
#      house_age  MRTS_distance  CS_nos  Price_house
# 31        29.6       769.4034       7         25.0
# 265       15.7       815.9314       4         38.1
# 319       34.6       272.6783       5         26.9

# %%
houses.isna().sum()
# Out:
# house_age        0
# MRTS_distance    0
# CS_nos           0
# Price_house      0
# dtype: int64

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   house_age      414 non-null    float64
#  1   MRTS_distance  414 non-null    float64
#  2   CS_nos         414 non-null    int64
#  3   Price_house    414 non-null    float64
# dtypes: float64(3), int64(1)
# memory usage: 13.1 KB

# %%
sns.pairplot(houses)

# %%
houses.corr()
# Out:
#                house_age  MRTS_distance    CS_nos  Price_house
# house_age       1.000000       0.025622  0.049593    -0.210567
# MRTS_distance   0.025622       1.000000 -0.602519    -0.673613
# CS_nos          0.049593      -0.602519  1.000000     0.571005
# Price_house    -0.210567      -0.673613  0.571005     1.000000

# %%
X = houses.drop('Price_house', axis=1)

# %%
y = houses['Price_house']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 12)

# %%
X_train.shape
# Out:
# (331, 3)

# %%
y_train.shape
# Out:
# (331,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([29.02008912, 51.4941166 , 46.11778861, 39.81162059, 37.49109149,
#        47.79076485, 47.8046247 , 38.07303229, 34.39693576, 43.34966759,
#        34.18195673, 30.25309039, 34.23288904, 51.95331374, 52.3331966 ,
#        43.51859681, 29.29344753, 40.55638865, 39.70065984, 44.7596896 ,
#        41.95417072, 43.86966814, 38.10158355, 17.74017607, 47.49296189,
#        45.49766878, 31.60073758, 43.31729914, 17.67796663, 38.7217687 ,
#        43.93935208, 34.4334439 , 46.79038986, 13.70911196, 37.88788914,
#        16.95072528, 17.00165759, 40.50695235, 32.80845457, 49.45210507,
#        52.28226429, 47.03282579, 40.88219776, 36.37623585, 38.66168872,
#        43.60144728, 43.57598113, 32.77816593, 43.18580657, 38.63622257,
#        44.23290616, 33.21536646, 39.95679401, 46.51095381, 33.18769159,
#        31.11354362, 52.57979014, 42.11890726, 46.24271389, 44.79399758,
#        16.9840857 , 46.51095381, 36.39958959, 34.39693576, 47.95742163,
#        17.83866565, 37.84851667, 43.86966814, 29.88689307, 40.03546014,
#        39.73291002, 32.21551046, 34.23288904, 34.42240192, 37.54452287,
#        39.58947864, 46.11538312, 43.32220694, 33.1789714 , 45.58322632,
#        12.34663584, 31.22635418, 48.19977443])

# %%
np.array(y_test)
# Out:
# array([22.3, 49.7, 52.2, 40.3, 35.3, 42.2, 51.6, 32.5, 33.4, 39.7, 30.1,
#        31.9, 25.3, 56.8, 58.1, 40.2, 19. , 37.3, 30. , 53.9, 48.5, 46.2,
#        41.1, 15.9, 51.8, 48.5, 29.5, 44.3, 27.3, 40. , 78.3, 35.6, 47.1,
#        17.4, 43.9, 16.7, 12.8, 37.4, 23. , 45.1, 63.9, 37.9, 36.8, 28.5,
#        32.2, 42.5, 39.3, 24.7, 34.6, 34.3, 43.4, 30.8, 37.4, 60.7, 29.8,
#        27. , 50.8, 36.7, 26.5, 51. , 18.3, 55. , 22.8, 30.7, 57.4, 41.2,
#        37.5, 51.4, 25.7, 44.2, 37.4, 23.1, 28.9, 31.7, 34.7, 60.7, 31.6,
#        42. , 20.8, 47.4, 15.5, 37. , 53.7])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.5923223518205945
